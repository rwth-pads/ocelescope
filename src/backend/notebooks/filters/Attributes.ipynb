# %%
import pm4py
ocel = pm4py.read_ocel2_xml("/home/grkmr/data/ocels/angular_github_commits_ocel.xml")

# %%
from typing import List, Literal, Union
import pandas as pd
import pm4py
from pm4py.objects.ocel.obj import OCEL
from pydantic.main import BaseModel


# --- Attribute Type Models ---

class IntegerAttribute(BaseModel):
    attribute: str
    type: Literal["integer"]
    min: int
    max: int


class FloatAttribute(BaseModel):
    attribute: str
    type: Literal["float"]
    min: float
    max: float


class BooleanAttribute(BaseModel):
    attribute: str
    type: Literal["boolean"]
    true_count: int
    false_count: int


class DateAttribute(BaseModel):
    attribute: str
    type: Literal["date"]
    min: str
    max: str


class NominalAttribute(BaseModel):
    attribute: str
    type: Literal["nominal"]
    num_unique: int


AttributeSummary = Union[
    IntegerAttribute,
    FloatAttribute,
    BooleanAttribute,
    DateAttribute,
    NominalAttribute,
]

# --- Utility Functions ---

def melt_df(df: pd.DataFrame, type_col: str, cols: list[str]) -> pd.DataFrame:
    return (
        df[[type_col] + cols]
        .melt(id_vars=type_col, var_name="attribute", value_name="value")
        .dropna(subset=["value"])
    )


def is_boolean_series_fast(series: pd.Series, lower_vals: pd.Series) -> bool:
    valid = {"true", "false", "yes", "no", "0", "1"}
    return set(lower_vals.unique()).issubset(valid) and lower_vals.nunique() <= 2


# --- Main Attribute Summary Logic ---

def summarize_attributes(df: pd.DataFrame, type_column: str) -> dict[str, List[AttributeSummary]]:
    summary_by_type: dict[str, List[AttributeSummary]] = {}

    grouped = df.groupby([type_column, "attribute"])

    for (type_name, attr), group in grouped:
        values = group["value"].dropna()
        str_vals = values.astype(str)
        lower_vals = str_vals.str.lower()

        attribute_type = "unknown"
        numeric_values = None
        date_values = None

        # Try boolean
        if is_boolean_series_fast(values, lower_vals):
            attribute_type = "boolean"

        # Try numeric
        if attribute_type == "unknown":
            try:
                numeric_values = pd.to_numeric(values, errors="raise")
                if (numeric_values % 1 == 0).all():
                    attribute_type = "integer"
                    numeric_values = numeric_values.astype(int)
                else:
                    attribute_type = "float"
            except Exception:
                pass

        # Try date
        if attribute_type == "unknown":
            try:
                    
                with warnings.catch_warnings():
                    warnings.simplefilter("ignore", UserWarning)
                    date_values = pd.to_datetime(values, errors="coerce")
                if date_values.notna().all():
                    attribute_type = "date"
            except Exception:
                pass

        # Fallback to nominal
        if attribute_type == "unknown":
            attribute_type = "nominal"

        # Create summary
        match attribute_type:
            case "integer":
                summary = IntegerAttribute(
                    attribute=attr,
                    type="integer",
                    min=int(numeric_values.min()),
                    max=int(numeric_values.max()),
                )
            case "float":
                summary = FloatAttribute(
                    attribute=attr,
                    type="float",
                    min=float(numeric_values.min()),
                    max=float(numeric_values.max()),
                )
            case "boolean":
                true_count = lower_vals.isin(["true", "yes", "1"]).sum()
                false_count = len(values) - true_count
                summary = BooleanAttribute(
                    attribute=attr,
                    type="boolean",
                    true_count=true_count,
                    false_count=false_count,
                )
            case "date":
                summary = DateAttribute(
                    attribute=attr,
                    type="date",
                    min=str(date_values.min()),
                    max=str(date_values.max()),
                )
            case "nominal":
                summary = NominalAttribute(
                    attribute=attr,
                    type="nominal",
                    num_unique=values.nunique(),
                )

        summary_by_type.setdefault(type_name, []).append(summary)

    return summary_by_type


# --- OCEL Integration Functions ---

def summarize_event_attributes(ocel: OCEL) -> dict[str, list[AttributeSummary]]:
    event_attribute_names = [
        col for col in pm4py.ocel_get_attribute_names(ocel) if col in ocel.events.columns
    ]

    melted_event_attributes = melt_df(
        ocel.events, ocel.event_activity, event_attribute_names
    )

    return summarize_attributes(melted_event_attributes, ocel.event_activity)


def summarize_object_attributes(ocel: OCEL) -> dict[str, list[AttributeSummary]]:
    obj_type_col = ocel.object_type_column

    attribute_names = pm4py.ocel_get_attribute_names(ocel)
    object_cols = [col for col in attribute_names if col in ocel.objects.columns]
    object_changes_cols = [
        col for col in attribute_names if col in ocel.object_changes.columns
    ]

    melted_objects = melt_df(
        ocel.objects.replace("null", pd.NA), obj_type_col, object_cols
    )
    melted_changes = melt_df(
        ocel.object_changes.replace("null", pd.NA), obj_type_col, object_changes_cols
    )

    metadata = pd.concat([melted_objects, melted_changes], ignore_index=True)

    return summarize_attributes(metadata, obj_type_col)

# %%
summarize_event_attributes(ocel)
# Out:
# {'add': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=313, max=5212),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=10),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=11),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=11)],
#  'address': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=988, max=988),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'aio': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=7636, max=9204),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=2),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=3),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=3)],
#  'benchmark': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=218, max=5683),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=2),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=3),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=3)],
#  'bug': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=159, max=4908),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=4),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=5),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=5)],
#  'build': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=1, max=27841),
#   NominalAttribute(attribute='Unnamed: 10', type='nominal', num_unique=2),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=130),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=3769),
#   NominalAttribute(attribute='merge', type='nominal', num_unique=3)],
#  'bump': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=4373, max=4373),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'check': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=6052, max=6052),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'chore': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=2, max=17961),
#   NominalAttribute(attribute='Unnamed: 10', type='nominal', num_unique=1),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=94),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1086),
#   NominalAttribute(attribute='merge', type='nominal', num_unique=2)],
#  'ci': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=3671, max=27826),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=58),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=957),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=958)],
#  'cleanup': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=134, max=5966),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=8),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=69),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=70)],
#  'code': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=7179, max=7179),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'condition': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=4316, max=4317),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=2),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=2)],
#  'configure': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=4720, max=4720),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'consolidated': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=7182, max=7182),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'copy': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=1072, max=1072),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'design': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=15, max=84),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=7),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=7)],
#  'developer.md': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=916, max=1059),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=2),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=2)],
#  'docs': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=37, max=27845),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1469),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=5589),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=5625)],
#  "don't": [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=606, max=4409),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=2),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=2),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=2)],
#  'edit': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=5440, max=5440),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'example': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=782, max=4794),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=2),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=6),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=6)],
#  'examples': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=1691, max=1967),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=3),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=3)],
#  'feat': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=31, max=27787),
#   NominalAttribute(attribute='Unnamed: 10', type='nominal', num_unique=3),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=235),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=2861),
#   NominalAttribute(attribute='merge', type='nominal', num_unique=5)],
#  'filetree': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=7180, max=7180),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'finished': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=5618, max=5618),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'first': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=12, max=12),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'fix': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=18, max=27825),
#   NominalAttribute(attribute='Unnamed: 10', type='nominal', num_unique=2),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=511),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=6049),
#   NominalAttribute(attribute='merge', type='nominal', num_unique=5)],
#  'form': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=5771, max=5771),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'format': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=550, max=550),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'include': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=6235, max=6235),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'initial': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=0, max=16858),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=2),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=2),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=2)],
#  'keep': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=6053, max=6053),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'make': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=343, max=3351),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=2),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=2),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=2)],
#  'merge': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=1331, max=1331),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=1, false_count=0)],
#  'misc': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=961, max=961),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'more': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=418, max=1194),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=2),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=2),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=2)],
#  'moved': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=13, max=14),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=2),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=2)],
#  'patch': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=3280, max=3280),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'perf': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=109, max=27821),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=51),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=372),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=375)],
#  'produce': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=2966, max=2966),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'read': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=990, max=990),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'readme': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=736, max=4451),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=2),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=2),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=2)],
#  'refactor': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=9, max=27846),
#   NominalAttribute(attribute='Unnamed: 10', type='nominal', num_unique=2),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=223),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=4072),
#   NominalAttribute(attribute='merge', type='nominal', num_unique=4)],
#  'release': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=565, max=27829),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=25),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=346),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=348)],
#  'remove': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=400, max=20536),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=8),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=8),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=8)],
#  'rendererv2': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=6759, max=6759),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'repackaging': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=4207, max=4208),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=2),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=2)],
#  'replaced': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=318, max=318),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'resolve': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=2951, max=2951),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'revert': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=1657, max=27818),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=46),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=465),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=465)],
#  'roll': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=4042, max=4042),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'router': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=5235, max=5235),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'squash': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=3243, max=3243),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'squash-me': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=1381, max=1381),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'style': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=68, max=22712),
#   NominalAttribute(attribute='Unnamed: 10', type='nominal', num_unique=1),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=62),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=200),
#   NominalAttribute(attribute='merge', type='nominal', num_unique=2)],
#  'table': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=7181, max=7181),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'temporary': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=2949, max=2949),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'test': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=28, max=27806),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=102),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1459),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1461)],
#  'text': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=5706, max=5706),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'tools': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=1994, max=3733),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=4),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=4)],
#  'transpiler': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=73, max=73),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'tweak': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=366, max=1026),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=2),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=2),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=2)],
#  'typo': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=3152, max=6266),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=5),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=5),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=5)],
#  'update': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=10, max=24933),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=23),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=30),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=34)],
#  'use': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=98, max=98),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'wip': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=4, max=4544),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=2),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=2),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=2)]}

# %%
from pandas.api.types import is_numeric_dtype, is_datetime64_any_dtype
import pandas as pd
from typing import Union,Optional
from dataclasses import dataclass

class BaseFilterConfig(BaseModel):
    mode: Optional[Literal["include", "exclude"]] = "include"


class AttributeFilterConfig(BaseFilterConfig):
    type: Literal["attribute"]
    target: Literal["event", "object"]
    attribute: str

    # Range filters
    min: Optional[Union[int, float, str]] = None
    max: Optional[Union[int, float, str]] = None

    # Nominal filters
    values: Optional[list[Union[str, int, float]]] = None
    regex: Optional[str] = None

@dataclass
class FilterResult:
    events: Optional[pd.Series] = None
    objects: Optional[pd.Series] = None
    e2o: Optional[pd.Series] = None
    o2o: Optional[pd.Series] = None
    


def filter_by_attribute(ocel: OCEL, config: AttributeFilterConfig) -> FilterResult:
    df = ocel.events if config.target == "event" else ocel.objects
    col = config.attribute

    if col not in df.columns:
        raise ValueError(f"Attribute '{col}' not found in {config.target} data")

    series = df[col]
    mask = pd.Series(True, index=series.index)

    # Handle numeric filtering
    if config.min is not None or config.max is not None:
        if is_numeric_dtype(series):
            numeric_series = series
        else:
            numeric_series = pd.to_numeric(series, errors="coerce")

        if config.min is not None:
            mask &= numeric_series >= float(config.min)
        if config.max is not None:
            mask &= numeric_series <= float(config.max)

    # Handle date filtering
    elif isinstance(config.min, str) or isinstance(config.max, str):
        if is_datetime64_any_dtype(series):
            date_series = series
        else:
            date_series = pd.to_datetime(series, errors="coerce")

        if config.min is not None:
            mask &= date_series >= pd.to_datetime(config.min)
        if config.max is not None:
            mask &= date_series <= pd.to_datetime(config.max)

    # Handle nominal filtering
    if config.values is not None:
        mask &= series.isin(config.values)

    if config.regex is not None:
        mask &= series.astype(str).str.contains(config.regex, regex=True, na=False)

    if config.mode == "exclude":
        mask = ~mask

    return FilterResult(
        events=mask if config.target == "event" else None,
        objects=mask if config.target == "object" else None
    )

# %%
summarize_event_attributes(ocel)
# Out:
# {'add': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=313, max=5212),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=10),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=11),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=11)],
#  'address': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=988, max=988),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'aio': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=7636, max=9204),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=2),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=3),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=3)],
#  'benchmark': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=218, max=5683),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=2),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=3),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=3)],
#  'bug': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=159, max=4908),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=4),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=5),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=5)],
#  'build': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=1, max=27841),
#   NominalAttribute(attribute='Unnamed: 10', type='nominal', num_unique=2),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=130),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=3769),
#   NominalAttribute(attribute='merge', type='nominal', num_unique=3)],
#  'bump': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=4373, max=4373),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'check': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=6052, max=6052),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'chore': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=2, max=17961),
#   NominalAttribute(attribute='Unnamed: 10', type='nominal', num_unique=1),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=94),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1086),
#   NominalAttribute(attribute='merge', type='nominal', num_unique=2)],
#  'ci': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=3671, max=27826),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=58),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=957),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=958)],
#  'cleanup': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=134, max=5966),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=8),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=69),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=70)],
#  'code': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=7179, max=7179),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'condition': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=4316, max=4317),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=2),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=2)],
#  'configure': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=4720, max=4720),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'consolidated': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=7182, max=7182),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'copy': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=1072, max=1072),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'design': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=15, max=84),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=7),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=7)],
#  'developer.md': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=916, max=1059),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=2),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=2)],
#  'docs': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=37, max=27845),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1469),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=5589),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=5625)],
#  "don't": [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=606, max=4409),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=2),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=2),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=2)],
#  'edit': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=5440, max=5440),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'example': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=782, max=4794),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=2),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=6),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=6)],
#  'examples': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=1691, max=1967),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=3),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=3)],
#  'feat': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=31, max=27787),
#   NominalAttribute(attribute='Unnamed: 10', type='nominal', num_unique=3),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=235),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=2861),
#   NominalAttribute(attribute='merge', type='nominal', num_unique=5)],
#  'filetree': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=7180, max=7180),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'finished': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=5618, max=5618),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'first': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=12, max=12),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'fix': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=18, max=27825),
#   NominalAttribute(attribute='Unnamed: 10', type='nominal', num_unique=2),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=511),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=6049),
#   NominalAttribute(attribute='merge', type='nominal', num_unique=5)],
#  'form': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=5771, max=5771),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'format': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=550, max=550),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'include': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=6235, max=6235),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'initial': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=0, max=16858),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=2),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=2),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=2)],
#  'keep': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=6053, max=6053),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'make': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=343, max=3351),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=2),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=2),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=2)],
#  'merge': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=1331, max=1331),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=1, false_count=0)],
#  'misc': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=961, max=961),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'more': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=418, max=1194),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=2),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=2),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=2)],
#  'moved': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=13, max=14),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=2),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=2)],
#  'patch': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=3280, max=3280),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'perf': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=109, max=27821),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=51),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=372),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=375)],
#  'produce': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=2966, max=2966),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'read': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=990, max=990),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'readme': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=736, max=4451),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=2),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=2),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=2)],
#  'refactor': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=9, max=27846),
#   NominalAttribute(attribute='Unnamed: 10', type='nominal', num_unique=2),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=223),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=4072),
#   NominalAttribute(attribute='merge', type='nominal', num_unique=4)],
#  'release': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=565, max=27829),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=25),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=346),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=348)],
#  'remove': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=400, max=20536),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=8),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=8),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=8)],
#  'rendererv2': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=6759, max=6759),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'repackaging': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=4207, max=4208),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=2),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=2)],
#  'replaced': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=318, max=318),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'resolve': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=2951, max=2951),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'revert': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=1657, max=27818),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=46),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=465),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=465)],
#  'roll': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=4042, max=4042),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'router': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=5235, max=5235),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'squash': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=3243, max=3243),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'squash-me': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=1381, max=1381),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'style': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=68, max=22712),
#   NominalAttribute(attribute='Unnamed: 10', type='nominal', num_unique=1),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=62),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=200),
#   NominalAttribute(attribute='merge', type='nominal', num_unique=2)],
#  'table': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=7181, max=7181),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'temporary': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=2949, max=2949),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'test': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=28, max=27806),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=102),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1459),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1461)],
#  'text': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=5706, max=5706),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'tools': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=1994, max=3733),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=4),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=4)],
#  'transpiler': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=73, max=73),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'tweak': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=366, max=1026),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=2),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=2),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=2)],
#  'typo': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=3152, max=6266),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=5),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=5),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=5)],
#  'update': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=10, max=24933),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=23),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=30),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=34)],
#  'use': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=98, max=98),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=1),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=1),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=1)],
#  'wip': [IntegerAttribute(attribute='Unnamed: 0', type='integer', min=4, max=4544),
#   NominalAttribute(attribute='author_name', type='nominal', num_unique=2),
#   NominalAttribute(attribute='commit_message', type='nominal', num_unique=2),
#   BooleanAttribute(attribute='merge', type='boolean', true_count=0, false_count=2)]}

# %%
ocel.events
# Out:
#                                        ocel:eid ocel:activity  \
# 0      6a3abf2366e2c32ce3460155903262fee01736c8       initial
# 1      afa761646472120edef1f9b01f219f125f20128e         build
# 2      45f8a5119488d28bf90311b2dd7fc55ee6f7d92a         build
# 6      e45ecd6d58986c45955081c14295cd28d984846e         chore
# 7      8afa421d75c95562060e35dbe8f576bd1e81c294         first
# ...                                         ...           ...
# 27842  8cd9663a9255e4f8dbddb0a888ea21da82082358       release
# 27843  eb0137de8ad498cf37ac238bdd472c8eab542a4d         build
# 27844  b3edcda9e600297441b5a55406f6b8a217826921         build
# 27845  e866d85e95a5974252e5a5bd79281cc33b3b1489          docs
# 27846  00bf05251b8fe687084fd2871210944ff750e30d          docs
#
#                  ocel:timestamp           author_name  merge Unnamed: 0  \
# 0     2014-09-18 09:12:01+00:00          Miško Hevery  False          0
# 1     2014-09-18 14:56:38+00:00          Tobias Bosch  False          1
# 2     2014-09-19 14:29:20+00:00          Tobias Bosch  False          6
# 6     2014-09-19 16:37:56+00:00          Misko Hevery  False          5
# 7     2014-09-19 16:38:37+00:00          Misko Hevery  False         12
# ...                         ...                   ...    ...        ...
# 27842 2023-09-06 18:23:35+00:00        Jessica Janiuk  False      27829
# 27843 2023-09-07 22:02:21+00:00                JoostK  False      27840
# 27844 2023-09-08 09:13:15+00:00  Kristiyan Kostadinov  False      27841
# 27845 2023-09-08 11:23:07+00:00            Alan Agius  False      27843
# 27846 2023-09-08 15:31:45+00:00         Angular Robot  False      27842
#
#                                           commit_message Unnamed: 10  \
# 0                                         Initial commit         NaN
# 1                                       build - refactor         NaN
# 2            build: prevent infinite loop during install         NaN
# 6             chare: changed gulp to support test folder         NaN
# 7      first chunk of interfaces that are valid via d...         NaN
# ...                                                  ...         ...
# 27842            release: cut the v17.0.0-next.3 release         NaN
# 27843  build: migrate `project_id` option to use `bes...         NaN
# 27844  build: attempt to deflake windows tests (#5170...         NaN
# 27845  docs: typo in what is angular (#51703)\n\nFix ...         NaN
# 27846  docs: update Angular CLI help [main] (#51704)\...         NaN
#
#       Unnamed: 11
# 0             NaN
# 1             NaN
# 2             NaN
# 6             NaN
# 7             NaN
# ...           ...
# 27842         NaN
# 27843         NaN
# 27844         NaN
# 27845         NaN
# 27846         NaN
#
# [27842 rows x 9 columns]

# %%
filter_by_attribute(ocel,AttributeFilterConfig(
    type="attribute",
    target="event",
    attribute="author_name",
    regex="Misko",
    mode="include"
)
)
# Out:
# FilterResult(events=0        False
# 1        False
# 2        False
# 6         True
# 7         True
#          ...
# 27842    False
# 27843    False
# 27844    False
# 27845    False
# 27846    False
# Length: 27842, dtype: bool, objects=None, e2o=None, o2o=None)
